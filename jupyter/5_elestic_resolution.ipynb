# %%
# %matplotlib widget
import scipp as sc
from trex.instrument import Instrument
import plopp as pp

central_wavelength = 1 * sc.Unit("Å")
mode = "High Flux"  # Chopper mode
rrm = 8
T_OFFSET = sc.scalar(1.7, unit="ms")

trex = Instrument(central_wavelength, rrm, mode, T_OFFSET)
wavelength_requested = trex.calculate_incoming_wavelength()
res = trex.model.run()

toa_det_edges = trex.detector.calculate_toa_bin_edges()

toa_bin_to_plot = sc.linspace(
    "toa", toa_det_edges.min(), toa_det_edges.max(), num=500 * (len(toa_det_edges) - 1)
)
hist_det = res.detectors["Detector"].data.hist(toa=toa_bin_to_plot)

fig = pp.plot({"Detector": hist_det}, grid=True)  # type:ignore
fig.ax.set_title(str(trex), fontsize=8)
fig
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 15
#      12 wavelength_requested = trex.calculate_incoming_wavelength()
#      13 res = trex.model.run()
# ---> 15 toa_det_edges = trex.detector.calculate_toa_bin_edges()
#      17 toa_bin_to_plot = sc.linspace(
#      18     "toa", toa_det_edges.min(), toa_det_edges.max(), num=500 * (len(toa_det_edges) - 1)
#      19 )
#      20 hist_det = res.detectors["Detector"].data.hist(toa=toa_bin_to_plot)
#
# AttributeError: 'Detector' object has no attribute 'calculate_toa_bin_edges'
